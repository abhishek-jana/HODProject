# %%
# load the autoreload extension
# %reload_ext autoreload
# Set extension to reload modules every time before executing code
# %autoreload 2

import numpy as np
import joblib
import os
from multiprocessing import Pool
import warnings
warnings.filterwarnings("ignore")

# %%
wp_path = '/mnt/data4/Abhishek/fidmock/wp'

wp_filenames = ['wp_subsample_'+f'{files:04d}'+'.npy' for files in range(100)]
wp = []
for files in wp_filenames:
    sample = np.load(os.path.join(wp_path,files))
    wp.append(sample[0])
wp_z = np.vstack(wp).T  
wp_filenames = ['wp_subsample_'+f'{files:04d}'+'.npy' for files in range(100,200)]
wp = []
for files in wp_filenames:
    sample = np.load(os.path.join(wp_path,files))
    wp.append(sample[0])
wp_x = np.vstack(wp).T 
wp_filenames = ['wp_subsample_'+f'{files:04d}'+'.npy' for files in range(200,300)]
wp = []
for files in wp_filenames:
    sample = np.load(os.path.join(wp_path,files))
    wp.append(sample[0])
wp_y = np.vstack(wp).T 


wpz_cov = np.cov(wp_z)
wpx_cov = np.cov(wp_x)
wpy_cov = np.cov(wp_y)
wp_cov = (wpz_cov + wpx_cov + wpy_cov)/3

# %%
filename = 'wp_model.sav'
# load the model from disk
model = joblib.load(filename)
wp_data = np.load('/mnt/data4/Abhishek/WP/wp_galaxies_0000.npy')[0]

# %%
wp_data
# Out:
# array([260.86534181, 243.32131603, 224.59096096, 204.64437357,
#        184.70260426, 165.6134697 , 147.41694039, 131.29157772,
#        116.21454283, 103.14360674,  91.18778846,  79.81283   ,
#         68.60657022,  58.56472449,  50.02942798,  42.88834362,
#         37.12308238,  32.15774451,  27.91447514,  24.26929413,
#         20.97716219,  18.00164184,  15.25353038,  12.74831873,
#         10.48728464,   8.45321655,   6.65530964,   5.10156874,
#          3.78859548,   2.69250056])

# %%
def wp_model(par):
    result = model.predict(par.reshape(1,-1))
    return result[0]

# %%
def log_likelihood(par , data, cov):
    M_cut,M1 ,sigma, kappa, alpha = par
    diff = data - wp_model(par)
    return  -0.5 * np.dot(diff, np.linalg.solve(cov, diff))

# %%
def log_prior(par):
    M_cut,M1 ,sigma, kappa, alpha = par
    if 12.0 < M_cut < 14.0 and 13.0 < M1 < 15.0 and -2 < sigma < 2.0 and -2 < kappa < 2.0 and -2 < alpha < 2.0:
        return 0.0
    return -np.inf

# %%
def log_probability(par, data, cov):
    lp = log_prior(par)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(par, data, cov)

# %%
x_truth = np.array([13.088658, 14.060000, 0.980000, 1.130000, 0.900000])

# %%
from scipy.optimize import minimize

np.random.seed(42)
nll = lambda *args: -log_likelihood(*args)
initial = x_truth + 0.1 * np.random.randn(5)
soln = minimize(nll, initial, args=(wp_data, wp_cov))
M_cut_ml,M1_ml,sigma_ml, kappa_ml, alpha_ml = soln.x

# %%
soln.x
# Out:
# array([13.13861552, 14.04648256,  1.04504351,  1.28265775,  0.87698902])

# %%
init = np.array([13.13861552, 14.04648256,  1.04504351,  1.28265775,  0.87698902])
import emcee
ndim = 5
nwalkers = 64
pos = init + 1e-4 * np.random.rand(nwalkers, ndim)

with Pool() as pool:
    filename = "new_wpmcmctest.h5"
    backend = emcee.backends.HDFBackend(filename)
    backend.reset(nwalkers, ndim)
    sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability, args=(wp_data, wp_cov),pool=pool)
    sampler.run_mcmc(pos, 300, store = True, progress=True)
# Out:
# 100%|██████████| 300/300 [07:15<00:00,  1.51s/it]

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(5, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["M_cut","M1" ,"sigma", "kappa", "alpha"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
# Out:
# Text(0.5, 0, 'step number')

# %%
import corner

fig = corner.corner(
    flat_samples, labels=labels, truths=x_truth,quantiles=[0.16, 0.5, 0.84]
)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
import emcee
sampler = emcee.backends.HDFBackend("new_wpmcmctest.h5")

# %%
flat_samples = sampler.get_chain( flat=True)
print(flat_samples.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-93cd0dcbde8f> in <module>
# ----> 1 flat_samples = sampler.get_chain( flat=True)
#       2 print(flat_samples.shape)
#
# ~/.local/lib/python3.7/site-packages/emcee/backends/backend.py in get_chain(self, **kwargs)
#      70
#      71         """
# ---> 72         return self.get_value("chain", **kwargs)
#      73
#      74     def get_blobs(self, **kwargs):
#
# ~/.local/lib/python3.7/site-packages/emcee/backends/hdf.py in get_value(self, name, flat, thin, discard)
#      99             iteration = g.attrs["iteration"]
#     100             if iteration <= 0:
# --> 101                 raise AttributeError("You must run the sampler with "
#     102                                      "'store == True' before accessing the "
#     103                                      "results")
#
# AttributeError: You must run the sampler with 'store == True' before accessing the results

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(5, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["M_cut","M1" ,"sigma", "kappa", "alpha"]
for i in range(5):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    #ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
# Out:
# Text(0.5, 0, 'step number')

# %%
tau = sampler.get_autocorr_time(tol=0)
burnin = int(2 * np.max(tau))
thin = int(0.5 * np.min(tau))
flat_samples = sampler.get_chain(discard=1000,thin = thin, flat=True)
print(flat_samples.shape)
# Out:
# (17250, 5)

# %%
import corner

fig = corner.corner(
    flat_samples, labels=labels, truths=x_truth,quantiles=[0.16, 0.5, 0.84]
)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
from getdist import plots, MCSamples

# %%
wp_sample = MCSamples(samples=flat_samples,names = labels, labels=labels, label='wp_sample')
# Out:
# Removed no burn in

# %%
g = plots.get_subplot_plotter()
g.triangle_plot([wp_sample], filled=True)
# Out:
# WARNING:root:auto bandwidth for M_cut very small or failed (h=0.0007188266729289933,N_eff=17250.0). Using fallback (h=0.01027647634613521)
# WARNING:root:auto bandwidth for M1 very small or failed (h=0.0013143618320448506,N_eff=17250.0). Using fallback (h=0.011569467573852747)
# WARNING:root:auto bandwidth for sigma very small or failed (h=0.0010318234679326222,N_eff=17250.0). Using fallback (h=0.0067963408905676774)
# WARNING:root:auto bandwidth for kappa very small or failed (h=0.0004370930647944263,N_eff=17250.0). Using fallback (h=0.004774526213071955)
# WARNING:root:auto bandwidth for alpha very small or failed (h=0.0004175151207258639,N_eff=17250.0). Using fallback (h=0.01247548745872897)
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density

# %%
g = plots.get_single_plotter(width_inch=6, ratio=3 / 5.)
g.settings.legend_fontsize = 12
g.plot_2d([wp_sample], 'M1', 'kappa', filled=True)
# Out:
# WARNING:root:fine_bins_2D not large enough for optimal density
# ((14.055038198061574, 14.060670846510517),
#  (1.106846808449405, 1.1396494892437303))

# %%
tau = sampler.get_autocorr_time(tol=0)
print(tau)
# Out:
# [175.09120669 235.03726568 174.22367585 299.03418372 144.40910364]

# %%
from IPython.display import display, Math

for i in range(5):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.5f}_{{-{1:.5f}}}^{{{2:.5f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{M_cut} = 13.08898_{-0.00029}^{0.00005}$
# $\displaystyle \mathrm{M1} = 14.05974_{-0.00079}^{0.00039}$
# $\displaystyle \mathrm{sigma} = 0.97996_{-0.00001}^{0.00001}$
# $\displaystyle \mathrm{kappa} = 1.12726_{-0.00114}^{0.00117}$
# $\displaystyle \mathrm{alpha} = 0.90121_{-0.00027}^{0.00045}$

# %%
x_truth
# Out:
# array([13.088658, 14.06    ,  0.98    ,  1.13    ,  0.9     ])
